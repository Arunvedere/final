# %%
import pandas as pd

# %%
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor

from sklearn.linear_model import LogisticRegression
from sklearn import preprocessing
from sklearn.metrics import roc_curve, auc

# %%
X=pd.read_csv("chronic.csv")

# %%
X
# Out:
#      age   bp     sg  al  su       rbc        pc         pcc          ba  bgr  \
# 0     48   80  1.020   1   0       NaN    normal  notpresent  notpresent  121
# 1      7   50  1.020   4   0       NaN    normal  notpresent  notpresent  NaN
# 2     62   80  1.010   2   3    normal    normal  notpresent  notpresent  423
# 3     48   70  1.005   4   0    normal  abnormal     present  notpresent  117
# 4     51   80  1.010   2   0    normal    normal  notpresent  notpresent  106
# 5     60   90  1.015   3   0       NaN       NaN  notpresent  notpresent   74
# 6     68   70  1.010   0   0       NaN    normal  notpresent  notpresent  100
# 7     24  NaN  1.015   2   4    normal  abnormal  notpresent  notpresent  410
# 8     52  100  1.015   3   0    normal  abnormal     present  notpresent  138
# 9     53   90  1.020   2   0  abnormal  abnormal     present  notpresent   70
# 10    50   60  1.010   2   4       NaN  abnormal     present  notpresent  490
# ...

# %%
X.describe()
# Out:
#               age          bp          sg          al          su         bgr  \
# count  391.000000  388.000000  353.000000  354.000000  351.000000  356.000000
# mean    51.483376   76.469072    1.017408    1.016949    0.450142  148.036517
# std     17.169714   13.683637    0.005717    1.352679    1.099191   79.281714
# min      2.000000   50.000000    1.005000    0.000000    0.000000   22.000000
# 25%     42.000000   70.000000    1.010000    0.000000    0.000000   99.000000
# 50%     55.000000   80.000000    1.020000    0.000000    0.000000  121.000000
# 75%     64.500000   80.000000    1.020000    2.000000    0.000000  163.000000
# max     90.000000  180.000000    1.025000    5.000000    5.000000  490.000000
#
#                bu          sc         sod         pot        hemo
# count  381.000000  383.000000  313.000000  312.000000  348.000000
# mean    57.425722    3.072454  137.528754    4.627244   12.526437
# std     50.503006    5.741126   10.408752    3.193904    2.912587
# ...

# %%
list(X.columns.values)
# Out:
# ['age',
#  'bp',
#  'sg',
#  'al',
#  'su',
#  'rbc',
#  'pc',
#  'pcc',
#  'ba',
#  'bgr',
#  'bu',
#  'sc',
#  'sod',
#  'pot',
#  'hemo',
#  'pcv',
#  'wc',
#  'rc',
#  'htn',
#  'dm',
#  'appet',
#  'pe',
#  'ane',
#  'class']

# %% [markdown]
# missing values can be handled by replacing the 'NaN'values with 'Zero'. so find out the coloums with missing values and fill them with 'Zero

# %%
null_col=['bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc','ba','bgr','bu','sc','sod','pot','hemo','pcv','wc','rc','htn','dm','cad','appet','pe','ane']
for i in range(0, 10, 1):
    X[null_col[i]].fillna(0, inplace=True)

# %%
chronic
# Out:
#      age   bp     sg  al  su       rbc        pc         pcc          ba  bgr  \
# 0     48   80  1.020   1   0         0    normal  notpresent  notpresent  121
# 1      7   50  1.020   4   0         0    normal  notpresent  notpresent    0
# 2     62   80  1.010   2   3    normal    normal  notpresent  notpresent  423
# 3     48   70  1.005   4   0    normal  abnormal     present  notpresent  117
# 4     51   80  1.010   2   0    normal    normal  notpresent  notpresent  106
# 5     60   90  1.015   3   0         0         0  notpresent  notpresent   74
# 6     68   70  1.010   0   0         0    normal  notpresent  notpresent  100
# 7     24    0  1.015   2   4    normal  abnormal  notpresent  notpresent  410
# 8     52  100  1.015   3   0    normal  abnormal     present  notpresent  138
# 9     53   90  1.020   2   0  abnormal  abnormal     present  notpresent   70
# 10    50   60  1.010   2   4         0  abnormal     present  notpresent  490
# ...

# %% [markdown]
# Numeric variables are taken by selecting only the variables which are not 'object' data types

# %%
numeric_variables = list(X.dtypes[X.dtypes != "object"].index)
X[numeric_variables].head()
# Out:
#    age  bp     sg  al  su  bgr  bu   sc  sod  pot  hemo
# 0   48  80  1.020   1   0  121  36  1.2  NaN  NaN  15.4
# 1    7  50  1.020   4   0    0  18  0.8  NaN  NaN  11.3
# 2   62  80  1.010   2   3  423  53  1.8  NaN  NaN   9.6
# 3   48  70  1.005   4   0  117  56  3.8  111  2.5  11.2
# 4   51  80  1.010   2   0  106  26  1.4  NaN  NaN  11.6

# %%
from sklearn.cross_validation import train_test_split
import numpy as np
np.random.seed(100)
X_train, X_test, y_train, y_test = train_test_split(X[numeric_variables], y, test_size=.2)

# %%
from sklearn.metrics import roc_auc_score

# %%
model = RandomForestClassifier(n_estimators=100, oob_score=True, random_state=72)

# %%
def describe_categorical(X):
    from IPython.display import display, HTML
    display(HTML(X[X.columns[X.dtypes == "object"]].describe().to_html()))

# %%
describe_categorical(X)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>rbc</th>
#       <th>pc</th>
#       <th>pcc</th>
#       <th>ba</th>
#       <th>pcv</th>
#       <th>wc</th>
#       <th>rc</th>
#       <th>htn</th>
#       <th>dm</th>
#       <th>appet</th>
#       <th>pe</th>
#       <th>ane</th>
#       <th>class</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>400</td>
#       <td>400</td>
#       <td>400</td>
#       <td>400</td>
#       <td>330</td>
#       <td>295</td>
#       <td>270</td>
#       <td>398</td>
#       <td>398</td>
#       <td>399</td>
#       <td>399</td>
#       <td>399</td>
#       <td>400</td>
#     </tr>
#     <tr>
#       <th>unique</th>
#       <td>3</td>
#       <td>3</td>
#       <td>3</td>
#       <td>3</td>
#       <td>44</td>
#       <td>92</td>
#       <td>46</td>
#       <td>2</td>
#       <td>5</td>
#       <td>2</td>
#       <td>2</td>
#       <td>2</td>
# ...

# %%
from sklearn.cross_validation import train_test_split
import numpy as np
np.random.seed(100)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2)

# %%
n_estimators=150
regressor = RandomForestRegressor(n_estimators, min_samples_split=1)
